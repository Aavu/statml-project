# %%
import os
import gc, sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline

# %%
def feature_engineering(is_train=True,debug=True):
    if is_train: 
        print("processing train.csv")
        if debug == True:
            df = pd.read_csv('train_V2.csv', nrows=10000)
        else:
            df = pd.read_csv('train_V2.csv')           

        df = df[df['maxPlace'] > 1]
    else:
        print("processing test.csv")
        df = pd.read_csv('test_V2.csv')
    
    print("remove some columns")
    target = 'winPlacePerc'

    print("Adding Features")
 
    df['headshotrate'] = df['kills']/df['headshotKills']
    df['killStreakrate'] = df['killStreaks']/df['kills']
    df['healthitems'] = df['heals'] + df['boosts']
    df['totalDistance'] = df['rideDistance'] + df["walkDistance"] + df["swimDistance"]
    df['killPlace_over_maxPlace'] = df['killPlace'] / df['maxPlace']
    df['headshotKills_over_kills'] = df['headshotKills'] / df['kills']
    df['distance_over_weapons'] = df['totalDistance'] / df['weaponsAcquired']
    df['walkDistance_over_heals'] = df['walkDistance'] / df['heals']
    df['walkDistance_over_kills'] = df['walkDistance'] / df['kills']
    df['killsPerWalkDistance'] = df['kills'] / df['walkDistance']
    df["skill"] = df["headshotKills"] + df["roadKills"]
    df[df == np.Inf] = np.NaN
    df[df == np.NINF] = np.NaN
    
    print("Removing Na's From DF")
    df.fillna(0, inplace=True)

    
    features = list(df.columns)
    features.remove("Id")
    features.remove("matchId")
    features.remove("groupId")
    features.remove("matchType")
    
    y = None
    
    if is_train: 
        print("get target")
        y = df.groupby(['matchId','groupId'])[target].agg('mean')
        features.remove(target)

    print("get group mean feature")
    agg = df.groupby(['matchId','groupId'])[features].agg('mean')
    agg_rank = agg.groupby('matchId')[features].rank(pct=True).reset_index()
    
    if is_train: df_out = agg.reset_index()[['matchId','groupId']]
    else: df_out = df[['matchId','groupId']]

    df_out = df_out.merge(agg.reset_index(), suffixes=["", ""], how='left', on=['matchId', 'groupId'])
    df_out = df_out.merge(agg_rank, suffixes=["_mean", "_mean_rank"], how='left', on=['matchId', 'groupId'])
    
    print("get group max feature")
    agg = df.groupby(['matchId','groupId'])[features].agg('max')
    agg_rank = agg.groupby('matchId')[features].rank(pct=True).reset_index()
    df_out = df_out.merge(agg.reset_index(), suffixes=["", ""], how='left', on=['matchId', 'groupId'])
    df_out = df_out.merge(agg_rank, suffixes=["_max", "_max_rank"], how='left', on=['matchId', 'groupId'])
    
    print("get group min feature")
    agg = df.groupby(['matchId','groupId'])[features].agg('min')
    agg_rank = agg.groupby('matchId')[features].rank(pct=True).reset_index()
    df_out = df_out.merge(agg.reset_index(), suffixes=["", ""], how='left', on=['matchId', 'groupId'])
    df_out = df_out.merge(agg_rank, suffixes=["_min", "_min_rank"], how='left', on=['matchId', 'groupId'])
    
    print("get group size feature")
    agg = df.groupby(['matchId','groupId']).size().reset_index(name='group_size')
    df_out = df_out.merge(agg, how='left', on=['matchId', 'groupId'])
    
    print("get match mean feature")
    agg = df.groupby(['matchId'])[features].agg('mean').reset_index()
    df_out = df_out.merge(agg, suffixes=["", "_match_mean"], how='left', on=['matchId'])

    print("get match size feature")
    agg = df.groupby(['matchId']).size().reset_index(name='match_size')
    df_out = df_out.merge(agg, how='left', on=['matchId'])
    
    df_out.drop(["matchId", "groupId"], axis=1, inplace=True)

    X = df_out
    
    del df, df_out, agg, agg_rank
    gc.collect()

    return X, y

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() 
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() 
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
x_train, y_train = feature_engineering(True,True)
x_test, _ = feature_engineering(False,True)
# Out:
# processing train.csv
# remove some columns
# Adding Features
# Removing Na's From DF
# get target
# get group mean feature
# get group max feature
# get group min feature
# get group size feature
# get match mean feature
# get match size feature
# processing test.csv
# remove some columns
# Adding Features
# Removing Na's From DF
# get group mean feature
# get group max feature
# get group min feature
# get group size feature
# get match mean feature
# get match size feature

# %%
def nn_model(input_shape=x_train.shape[1], hidden_size=64):
    model = Sequential()
    model.add(Dense(hidden_size, input_dim=input_shape, kernel_initializer='normal'))
    model.add(LeakyReLU(0.1))
    model.add(Dense(hidden_size, kernel_initializer='normal'))
    model.add(LeakyReLU(0.1))
    model.add(Dense(hidden_size, kernel_initializer='normal'))
    model.add(LeakyReLU(0.1))
    model.add(Dense(hidden_size, kernel_initializer='normal'))
    model.add(LeakyReLU(0.1))

    model.add(Dense(1, kernel_initializer='normal'))
    
    model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    return model

# %%
def train_val_split(x_train, y_train):
    train_index = round(int(x_train.shape[0]*0.8))
    dev_X = x_train[:train_index] 
    val_X = x_train[train_index:]
    dev_y = y_train[:train_index] 
    val_y = y_train[train_index:]
    return dev_X, val_X, dev_y, val_y

# %%
np.random.seed(42)

std_scaler = StandardScaler().fit(x_train)
x_train = std_scaler.transform(x_train)
x_test = std_scaler.transform(x_test)

mlp_model = nn_model(x_train.shape[1], hidden_size=64)
history = mlp_model.fit(x_train, y_train, batch_size=128, epochs=100, verbose=1, validation_split=0.1, shuffle=True)
pred_test_mlp = mlp_model.predict(x_test)
# Out:
# /anaconda3/envs/ML/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/envs/ML/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# /anaconda3/envs/ML/lib/python3.6/site-packages/ipykernel/__main__.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# Train on 8973 samples, validate on 998 samples
# Epoch 1/100
# 8973/8973 [==============================] - 1s 57us/step - loss: 0.1890 - mean_absolute_error: 0.1890 - val_loss: 0.0994 - val_mean_absolute_error: 0.0994
# Epoch 2/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830
# Epoch 3/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0808 - mean_absolute_error: 0.0808 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840
# Epoch 4/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0790 - mean_absolute_error: 0.0790 - val_loss: 0.0762 - val_mean_absolute_error: 0.0762
# Epoch 5/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0743 - mean_absolute_error: 0.0743 - val_loss: 0.0758 - val_mean_absolute_error: 0.0758
# Epoch 6/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0733 - mean_absolute_error: 0.0733 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734
# Epoch 7/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0725 - mean_absolute_error: 0.0725 - val_loss: 0.0822 - val_mean_absolute_error: 0.0822
# Epoch 8/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0727 - mean_absolute_error: 0.0727 - val_loss: 0.0755 - val_mean_absolute_error: 0.0755
# Epoch 9/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0714 - mean_absolute_error: 0.0714 - val_loss: 0.0792 - val_mean_absolute_error: 0.0792
# Epoch 10/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0710 - mean_absolute_error: 0.0710 - val_loss: 0.0743 - val_mean_absolute_error: 0.0743
# Epoch 11/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740
# Epoch 12/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0692 - mean_absolute_error: 0.0692 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 13/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 14/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 15/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 16/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0668 - mean_absolute_error: 0.0668 - val_loss: 0.0758 - val_mean_absolute_error: 0.0758
# Epoch 17/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0668 - mean_absolute_error: 0.0668 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 18/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0678 - mean_absolute_error: 0.0678 - val_loss: 0.0747 - val_mean_absolute_error: 0.0747
# Epoch 19/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 20/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0664 - mean_absolute_error: 0.0664 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 21/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728
# Epoch 22/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0749 - val_mean_absolute_error: 0.0749
# Epoch 23/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0673 - mean_absolute_error: 0.0673 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 24/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0661 - mean_absolute_error: 0.0661 - val_loss: 0.0719 - val_mean_absolute_error: 0.0719
# Epoch 25/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0654 - mean_absolute_error: 0.0654 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 26/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 27/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0659 - mean_absolute_error: 0.0659 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 28/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 29/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.0772 - val_mean_absolute_error: 0.0772
# Epoch 30/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0655 - mean_absolute_error: 0.0655 - val_loss: 0.0690 - val_mean_absolute_error: 0.0690
# Epoch 31/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 32/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0644 - mean_absolute_error: 0.0644 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 33/100
# 8973/8973 [==============================] - 0s 19us/step - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 34/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711
# Epoch 35/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0635 - mean_absolute_error: 0.0635 - val_loss: 0.0750 - val_mean_absolute_error: 0.0750
# Epoch 36/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 37/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0619 - mean_absolute_error: 0.0619 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 38/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0616 - mean_absolute_error: 0.0616 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711
# Epoch 39/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739
# Epoch 40/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714
# Epoch 41/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0617 - mean_absolute_error: 0.0617 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 42/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0762 - val_mean_absolute_error: 0.0762
# Epoch 43/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0614 - mean_absolute_error: 0.0614 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 44/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0604 - mean_absolute_error: 0.0604 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 45/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 46/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746
# Epoch 47/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.0741 - val_mean_absolute_error: 0.0741
# Epoch 48/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0602 - mean_absolute_error: 0.0602 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 49/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0591 - mean_absolute_error: 0.0591 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 50/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 51/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0590 - mean_absolute_error: 0.0590 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 52/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0592 - mean_absolute_error: 0.0592 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 53/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714
# Epoch 54/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0588 - mean_absolute_error: 0.0588 - val_loss: 0.0759 - val_mean_absolute_error: 0.0759
# Epoch 55/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0585 - mean_absolute_error: 0.0585 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 56/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0581 - mean_absolute_error: 0.0581 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 57/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 58/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0581 - mean_absolute_error: 0.0581 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 59/100
# 8973/8973 [==============================] - 0s 19us/step - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721
# Epoch 60/100
# 8973/8973 [==============================] - 0s 19us/step - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 61/100
# 8973/8973 [==============================] - 0s 19us/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 62/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0560 - mean_absolute_error: 0.0560 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 63/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 64/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723
# Epoch 65/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
# Epoch 66/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 67/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 68/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0556 - mean_absolute_error: 0.0556 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686
# Epoch 69/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 70/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739
# Epoch 71/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 72/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0538 - mean_absolute_error: 0.0538 - val_loss: 0.0752 - val_mean_absolute_error: 0.0752
# Epoch 73/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 74/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 75/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 76/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 77/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 78/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0532 - mean_absolute_error: 0.0532 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 79/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 80/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 81/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0530 - mean_absolute_error: 0.0530 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 82/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739
# Epoch 83/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 84/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715
# Epoch 85/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0527 - mean_absolute_error: 0.0527 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 86/100
# 8973/8973 [==============================] - 0s 16us/step - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 87/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 88/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 89/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0718 - val_mean_absolute_error: 0.0718
# Epoch 90/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0517 - mean_absolute_error: 0.0517 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 91/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0513 - mean_absolute_error: 0.0513 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 92/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0720 - val_mean_absolute_error: 0.0720
# Epoch 93/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0513 - mean_absolute_error: 0.0513 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 94/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0506 - mean_absolute_error: 0.0506 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 95/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795
# Epoch 96/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0733 - val_mean_absolute_error: 0.0733
# Epoch 97/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0741 - val_mean_absolute_error: 0.0741
# Epoch 98/100
# 8973/8973 [==============================] - 0s 18us/step - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721
# Epoch 99/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 100/100
# 8973/8973 [==============================] - 0s 17us/step - loss: 0.0496 - mean_absolute_error: 0.0496 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721

# %%
plt.plot(history.history['val_loss']);
plt.plot(history.history['loss']);
